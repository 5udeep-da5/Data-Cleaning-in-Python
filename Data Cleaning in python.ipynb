# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("cricket_dataset.csv")

# %%
df.head(10)
# Out:
#                 Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0     DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1       AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 2       HC Brook (ENG)  2022-2024   13    21   1  1231   186  61.55   1351
# 3      RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4      GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# 5    H Sutcliffe (ENG)  1924-1935   54    84   9  4555   194  60.73  6558+
# 6      E Paynter (ENG)  1931-1939   20    31   5  1540   243  59.23  1288+
# 7  KF Barrington (ENG)  1955-1968   82   131  15  6806   256  58.67  4957+
# 8       ED Weekes (WI)  1948-1958   48    81   5  4455   207  58.61    NaN
# 9     WR Hammond (ENG)  1927-1947   85   140  16  7249  336*  58.45  7491+
#
#       SR  100  50  0   4s  6s
# 0  58.60   29  13  7  626   6
# 1  55.68    5   4  2  186   5
# 2  91.11    4   8  1  146  24
# 3  54.48    7  11  1  246  11
# 4  56.00   10   5  2  104   1
# 5  34.59   16  23  2  202   6
# 6  45.88    4   7  3  125   4
# 7  42.42   20  35  5  591  27
# 8    NaN   15  19  6  258   2
# 9  38.07   22  24  4  419  27

# %%
# Rename Multiple columns 
# Check for null values and conduct null value treatment
# drop duplicates
# Split country from the player name
# Split career span into start and end date & find career length
# drop Span column
# Questions:
# average career length of players
# average batting strike rate who played over 10 years
# number of player before 1970
# max highest innings score by country

# %%
# Rename multiple columns

# %%
df= df.rename(columns={'Mat':'Matches', 'NO': 'Not_outs', 'HS':'Highest_score', 'Ave':'Average', 
                   'BF':'Balls_faced','SR':'Strike_rate'})

# %%
df.head(10)
# Out:
#                 Player       Span  Matches  Inns  Not_outs  Runs  \
# 0     DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1       AC Voges (AUS)  2015-2016       20    31         7  1485
# 2       HC Brook (ENG)  2022-2024       13    21         1  1231
# 3      RG Pollock (SA)  1963-1970       23    41         4  2256
# 4      GA Headley (WI)  1930-1954       22    40         4  2190
# 5    H Sutcliffe (ENG)  1924-1935       54    84         9  4555
# 6      E Paynter (ENG)  1931-1939       20    31         5  1540
# 7  KF Barrington (ENG)  1955-1968       82   131        15  6806
# 8       ED Weekes (WI)  1948-1958       48    81         5  4455
# 9     WR Hammond (ENG)  1927-1947       85   140        16  7249
#
#   Highest_score  Average Balls_faced  Strike_rate  100  50  0   4s  6s
# 0           334    99.94       9800+        58.60   29  13  7  626   6
# 1          269*    61.87        2667        55.68    5   4  2  186   5
# 2           186    61.55        1351        91.11    4   8  1  146  24
# 3           274    60.97       1707+        54.48    7  11  1  246  11
# 4          270*    60.83        416+        56.00   10   5  2  104   1
# 5           194    60.73       6558+        34.59   16  23  2  202   6
# 6           243    59.23       1288+        45.88    4   7  3  125   4
# 7           256    58.67       4957+        42.42   20  35  5  591  27
# 8           207    58.61         NaN          NaN   15  19  6  258   2
# 9          336*    58.45       7491+        38.07   22  24  4  419  27

# %%
# Check for null values and conduct null value treatment

# %%
df.isnull().sum()
# Out:
# Player           0
# Span             0
# Matches          0
# Inns             0
# Not_outs         0
# Runs             0
# Highest_score    0
# Average          0
# Balls_faced      3
# Strike_rate      3
# 100              0
# 50               0
# 0                0
# 4s               0
# 6s               0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Player           False
# Span             False
# Matches          False
# Inns             False
# Not_outs         False
# Runs             False
# Highest_score    False
# Average          False
# Balls_faced       True
# Strike_rate       True
# 100              False
# 50               False
# 0                False
# 4s               False
# 6s               False
# dtype: bool

# %%
df[df.Balls_faced.isna()==1]
# Out:
#                   Player       Span  Matches  Inns  Not_outs  Runs  \
# 8         ED Weekes (WI)  1948-1958       48    81         5  4455
# 14       CL Walcott (WI)  1948-1960       44    74         7  3798
# 57  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
#
#    Highest_score  Average Balls_faced  Strike_rate  100  50  0   4s  6s
# 8            207    58.61         NaN          NaN   15  19  6  258   2
# 14           220    56.68         NaN          NaN   15  14  1  107  11
# 57          144*    48.79         NaN          NaN    5   6  3   51   0

# %%
df[df.Strike_rate.isna()==1]
# Out:
#                   Player       Span  Matches  Inns  Not_outs  Runs  \
# 8         ED Weekes (WI)  1948-1958       48    81         5  4455
# 14       CL Walcott (WI)  1948-1960       44    74         7  3798
# 57  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
#
#    Highest_score  Average Balls_faced  Strike_rate  100  50  0   4s  6s
# 8            207    58.61         NaN          NaN   15  19  6  258   2
# 14           220    56.68         NaN          NaN   15  14  1  107  11
# 57          144*    48.79         NaN          NaN    5   6  3   51   0

# %%
df.Balls_faced = df.Balls_faced.fillna(0)

# %%
df[df.Player=='Hon.FS Jackson (ENG)']
# Out:
#                   Player       Span  Matches  Inns  Not_outs  Runs  \
# 57  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
#
#    Highest_score  Average Balls_faced  Strike_rate  100  50  0  4s  6s
# 57          144*    48.79           0          NaN    5   6  3  51   0

# %%
df.Strike_rate = df.Strike_rate.fillna(0)

# %%
df[df.Player=='CL Walcott (WI)']
# Out:
#              Player       Span  Matches  Inns  Not_outs  Runs Highest_score  \
# 14  CL Walcott (WI)  1948-1960       44    74         7  3798           220
#
#     Average Balls_faced  Strike_rate  100  50  0   4s  6s
# 14    56.68           0          0.0   15  14  1  107  11

# %%
df.head(10)
# Out:
#                 Player       Span  Matches  Inns  Not_outs  Runs  \
# 0     DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1       AC Voges (AUS)  2015-2016       20    31         7  1485
# 2       HC Brook (ENG)  2022-2024       13    21         1  1231
# 3      RG Pollock (SA)  1963-1970       23    41         4  2256
# 4      GA Headley (WI)  1930-1954       22    40         4  2190
# 5    H Sutcliffe (ENG)  1924-1935       54    84         9  4555
# 6      E Paynter (ENG)  1931-1939       20    31         5  1540
# 7  KF Barrington (ENG)  1955-1968       82   131        15  6806
# 8       ED Weekes (WI)  1948-1958       48    81         5  4455
# 9     WR Hammond (ENG)  1927-1947       85   140        16  7249
#
#   Highest_score  Average Balls_faced  Strike_rate  100  50  0   4s  6s
# 0           334    99.94       9800+        58.60   29  13  7  626   6
# 1          269*    61.87        2667        55.68    5   4  2  186   5
# 2           186    61.55        1351        91.11    4   8  1  146  24
# 3           274    60.97       1707+        54.48    7  11  1  246  11
# 4          270*    60.83        416+        56.00   10   5  2  104   1
# 5           194    60.73       6558+        34.59   16  23  2  202   6
# 6           243    59.23       1288+        45.88    4   7  3  125   4
# 7           256    58.67       4957+        42.42   20  35  5  591  27
# 8           207    58.61           0         0.00   15  19  6  258   2
# 9          336*    58.45       7491+        38.07   22  24  4  419  27

# %%
# drop duplicates

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df[df.Player.duplicated()==1]
# Out:
#                 Player       Span  Matches  Inns  Not_outs   Runs  \
# 24  SR Tendulkar (IND)  1989-2013      200   329        33  15921
# 28  R Dravid (ICC/IND)  1996-2012      164   286        32  13288
# 51  V Sehwag (ICC/IND)  2001-2013      104   180         6   8586
#
#    Highest_score  Average Balls_faced  Strike_rate  100  50   0    4s  6s
# 24          248*    53.78      29437+        54.04   51  68  14  2058  69
# 28           270    52.31       31258        42.51   36  63   8  1654  21
# 51           319    49.34       10441        82.23   23  32  16  1233  91

# %%
df[df.Player.isin(['SR Tendulkar (IND)', 'R Dravid (ICC/IND)', 'V Sehwag (ICC/IND)'])]
# Out:
#                 Player       Span  Matches  Inns  Not_outs   Runs  \
# 23  SR Tendulkar (IND)  1989-2013      200   329        33  15921
# 24  SR Tendulkar (IND)  1989-2013      200   329        33  15921
# 27  R Dravid (ICC/IND)  1996-2012      164   286        32  13288
# 28  R Dravid (ICC/IND)  1996-2012      164   286        32  13288
# 50  V Sehwag (ICC/IND)  2001-2013      104   180         6   8586
# 51  V Sehwag (ICC/IND)  2001-2013      104   180         6   8586
#
#    Highest_score  Average Balls_faced  Strike_rate  100  50   0    4s  6s
# 23          248*    53.78      29437+        54.04   51  68  14  2058  69
# 24          248*    53.78      29437+        54.04   51  68  14  2058  69
# 27           270    52.31       31258        42.51   36  63   8  1654  21
# 28           270    52.31       31258        42.51   36  63   8  1654  21
# 50           319    49.34       10441        82.23   23  32  16  1233  91
# 51           319    49.34       10441        82.23   23  32  16  1233  91

# %%
df=df.drop_duplicates()

# %%
df[df.Player.isin(['SR Tendulkar (IND)', 'R Dravid (ICC/IND)', 'V Sehwag (ICC/IND)'])]
# Out:
#                 Player       Span  Matches  Inns  Not_outs   Runs  \
# 23  SR Tendulkar (IND)  1989-2013      200   329        33  15921
# 27  R Dravid (ICC/IND)  1996-2012      164   286        32  13288
# 50  V Sehwag (ICC/IND)  2001-2013      104   180         6   8586
#
#    Highest_score  Average Balls_faced  Strike_rate  100  50   0    4s  6s
# 23          248*    53.78      29437+        54.04   51  68  14  2058  69
# 27           270    52.31       31258        42.51   36  63   8  1654  21
# 50           319    49.34       10441        82.23   23  32  16  1233  91

# %%
# Split country from the player name

# %%
df.Player.str.split(pat = '(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [AC Voges , AUS)]
# 2        [HC Brook , ENG)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
#               ...
# 60     [KD Walters , AUS)]
# 61    [GC Smith , ICC/SA)]
# 62    [WH Ponsford , AUS)]
# 63      [SJ McCabe , AUS)]
# 64     [DR Jardine , ENG)]
# Name: Player, Length: 62, dtype: object

# %%
df['Country']=df.Player.str.split(pat = '(').str[1]

# %%
df.Country=df.Country.str.split(pat=')').str[0]

# %%
df.head()
# Out:
#              Player  Matches  Inns  Not_outs  Runs Highest_score  Average  \
# 0  DG Bradman (AUS)       52    80        10  6996           334    99.94
# 1    AC Voges (AUS)       20    31         7  1485          269*    61.87
# 2    HC Brook (ENG)       13    21         1  1231           186    61.55
# 3   RG Pollock (SA)       23    41         4  2256           274    60.97
# 4   GA Headley (WI)       22    40         4  2190          270*    60.83
#
#   Balls_faced  Strike_rate  100  50  0   4s  6s Rookie_year Final_year Country
# 0       9800+        58.60   29  13  7  626   6        1928       1948     AUS
# 1        2667        55.68    5   4  2  186   5        2015       2016     AUS
# 2        1351        91.11    4   8  1  146  24        2022       2024     ENG
# 3       1707+        54.48    7  11  1  246  11        1963       1970      SA
# 4        416+        56.00   10   5  2  104   1        1930       1954      WI

# %%
df.Player=df.Player.str.split(pat = '(').str[0]

# %%
df.head(10)
# Out:
#            Player  Matches  Inns  Not_outs  Runs Highest_score  Average  \
# 0     DG Bradman        52    80        10  6996           334    99.94
# 1       AC Voges        20    31         7  1485          269*    61.87
# 2       HC Brook        13    21         1  1231           186    61.55
# 3     RG Pollock        23    41         4  2256           274    60.97
# 4     GA Headley        22    40         4  2190          270*    60.83
# 5    H Sutcliffe        54    84         9  4555           194    60.73
# 6      E Paynter        20    31         5  1540           243    59.23
# 7  KF Barrington        82   131        15  6806           256    58.67
# 8      ED Weekes        48    81         5  4455           207    58.61
# 9     WR Hammond        85   140        16  7249          336*    58.45
#
#   Balls_faced  Strike_rate  100  50  0   4s  6s Rookie_year Final_year Country
# 0       9800+        58.60   29  13  7  626   6        1928       1948     AUS
# 1        2667        55.68    5   4  2  186   5        2015       2016     AUS
# 2        1351        91.11    4   8  1  146  24        2022       2024     ENG
# 3       1707+        54.48    7  11  1  246  11        1963       1970      SA
# 4        416+        56.00   10   5  2  104   1        1930       1954      WI
# 5       6558+        34.59   16  23  2  202   6        1924       1935     ENG
# 6       1288+        45.88    4   7  3  125   4        1931       1939     ENG
# 7       4957+        42.42   20  35  5  591  27        1955       1968     ENG
# 8           0         0.00   15  19  6  258   2        1948       1958      WI
# 9       7491+        38.07   22  24  4  419  27        1927       1947     ENG

# %%
# Split career span into start and end date & find career length

# %%
df.Span.str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2015, 2016]
# 2     [2022, 2024]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 60    [1965, 1981]
# 61    [2002, 2014]
# 62    [1924, 1934]
# 63    [1930, 1938]
# 64    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Rookie_year']=df.Span.str.split(pat = '-').str[0]
# Out:
# C:\Users\91959\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Final_year']=df.Span.str.split(pat = '-').str[1]
# Out:
# C:\Users\91959\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head(10)
# Out:
#                 Player       Span  Matches  Inns  Not_outs  Runs  \
# 0     DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1       AC Voges (AUS)  2015-2016       20    31         7  1485
# 2       HC Brook (ENG)  2022-2024       13    21         1  1231
# 3      RG Pollock (SA)  1963-1970       23    41         4  2256
# 4      GA Headley (WI)  1930-1954       22    40         4  2190
# 5    H Sutcliffe (ENG)  1924-1935       54    84         9  4555
# 6      E Paynter (ENG)  1931-1939       20    31         5  1540
# 7  KF Barrington (ENG)  1955-1968       82   131        15  6806
# 8       ED Weekes (WI)  1948-1958       48    81         5  4455
# 9     WR Hammond (ENG)  1927-1947       85   140        16  7249
#
#   Highest_score  Average Balls_faced  Strike_rate  100  50  0   4s  6s  \
# 0           334    99.94       9800+        58.60   29  13  7  626   6
# 1          269*    61.87        2667        55.68    5   4  2  186   5
# 2           186    61.55        1351        91.11    4   8  1  146  24
# 3           274    60.97       1707+        54.48    7  11  1  246  11
# 4          270*    60.83        416+        56.00   10   5  2  104   1
# 5           194    60.73       6558+        34.59   16  23  2  202   6
# 6           243    59.23       1288+        45.88    4   7  3  125   4
# 7           256    58.67       4957+        42.42   20  35  5  591  27
# 8           207    58.61           0         0.00   15  19  6  258   2
# 9          336*    58.45       7491+        38.07   22  24  4  419  27
#
#   Rookie_year Final_year
# 0        1928       1948
# 1        2015       2016
# 2        2022       2024
# 3        1963       1970
# 4        1930       1954
# 5        1924       1935
# 6        1931       1939
# 7        1955       1968
# 8        1948       1958
# 9        1927       1947

# %%
df= df.drop(['Span'], axis=1)

# %%
df.head(10)
# Out:
#                 Player  Matches  Inns  Not_outs  Runs Highest_score  Average  \
# 0     DG Bradman (AUS)       52    80        10  6996           334    99.94
# 1       AC Voges (AUS)       20    31         7  1485          269*    61.87
# 2       HC Brook (ENG)       13    21         1  1231           186    61.55
# 3      RG Pollock (SA)       23    41         4  2256           274    60.97
# 4      GA Headley (WI)       22    40         4  2190          270*    60.83
# 5    H Sutcliffe (ENG)       54    84         9  4555           194    60.73
# 6      E Paynter (ENG)       20    31         5  1540           243    59.23
# 7  KF Barrington (ENG)       82   131        15  6806           256    58.67
# 8       ED Weekes (WI)       48    81         5  4455           207    58.61
# 9     WR Hammond (ENG)       85   140        16  7249          336*    58.45
#
#   Balls_faced  Strike_rate  100  50  0   4s  6s Rookie_year Final_year
# 0       9800+        58.60   29  13  7  626   6        1928       1948
# 1        2667        55.68    5   4  2  186   5        2015       2016
# 2        1351        91.11    4   8  1  146  24        2022       2024
# 3       1707+        54.48    7  11  1  246  11        1963       1970
# 4        416+        56.00   10   5  2  104   1        1930       1954
# 5       6558+        34.59   16  23  2  202   6        1924       1935
# 6       1288+        45.88    4   7  3  125   4        1931       1939
# 7       4957+        42.42   20  35  5  591  27        1955       1968
# 8           0         0.00   15  19  6  258   2        1948       1958
# 9       7491+        38.07   22  24  4  419  27        1927       1947

# %%
# Some more Data cleaning

# %%
df.Highest_score=df.Highest_score.str.split(pat = '*').str[0]

# %%
df.head()
# Out:
#         Player  Matches  Inns  Not_outs  Runs Highest_score  Average  \
# 0  DG Bradman        52    80        10  6996           334    99.94
# 1    AC Voges        20    31         7  1485           269    61.87
# 2    HC Brook        13    21         1  1231           186    61.55
# 3  RG Pollock        23    41         4  2256           274    60.97
# 4  GA Headley        22    40         4  2190           270    60.83
#
#   Balls_faced  Strike_rate  100  50  0   4s  6s Rookie_year Final_year Country
# 0       9800+        58.60   29  13  7  626   6        1928       1948     AUS
# 1        2667        55.68    5   4  2  186   5        2015       2016     AUS
# 2        1351        91.11    4   8  1  146  24        2022       2024     ENG
# 3       1707+        54.48    7  11  1  246  11        1963       1970      SA
# 4        416+        56.00   10   5  2  104   1        1930       1954      WI

# %%
df.Balls_faced = df.Balls_faced.str.split(pat = '+').str[0]

# %%
df.head()
# Out:
#         Player  Matches  Inns  Not_outs  Runs Highest_score  Average  \
# 0  DG Bradman        52    80        10  6996           334    99.94
# 1    AC Voges        20    31         7  1485           269    61.87
# 2    HC Brook        13    21         1  1231           186    61.55
# 3  RG Pollock        23    41         4  2256           274    60.97
# 4  GA Headley        22    40         4  2190           270    60.83
#
#   Balls_faced  Strike_rate  100  50  0   4s  6s Rookie_year Final_year Country
# 0        9800        58.60   29  13  7  626   6        1928       1948     AUS
# 1        2667        55.68    5   4  2  186   5        2015       2016     AUS
# 2        1351        91.11    4   8  1  146  24        2022       2024     ENG
# 3        1707        54.48    7  11  1  246  11        1963       1970      SA
# 4         416        56.00   10   5  2  104   1        1930       1954      WI

# %%
# Check datatypes

# %%
df.dtypes
# Out:
# Player            object
# Matches            int64
# Inns               int64
# Not_outs           int64
# Runs               int64
# Highest_score     object
# Average          float64
# Balls_faced       object
# Strike_rate      float64
# 100                int64
# 50                 int64
# 0                  int64
# 4s                 int64
# 6s                 int64
# Rookie_year       object
# Final_year        object
# Country           object
# dtype: object

# %%
# Highest Score - Int, Balls Faced - Int, Strike_rate - Int, Rookie year - Int, Final Year - Int

# %%
df.Highest_score = df.Highest_score.astype('int')

# %%
df.dtypes
# Out:
# Player            object
# Matches            int64
# Inns               int64
# Not_outs           int64
# Runs               int64
# Highest_score      int32
# Average          float64
# Balls_faced       object
# Strike_rate      float64
# 100                int64
# 50                 int64
# 0                  int64
# 4s                 int64
# 6s                 int64
# Rookie_year       object
# Final_year        object
# Country           object
# dtype: object

# %%
df=df.astype({'Rookie_year':'int', 'Final_year':'int'})

# %%
df.dtypes
# Out:
# Player            object
# Matches            int64
# Inns               int64
# Not_outs           int64
# Runs               int64
# Highest_score      int32
# Average          float64
# Balls_faced       object
# Strike_rate      float64
# 100                int64
# 50                 int64
# 0                  int64
# 4s                 int64
# 6s                 int64
# Rookie_year        int32
# Final_year         int32
# Country           object
# dtype: object

# %%
df.Balls_faced= df.Balls_faced.astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-93c5c1b553da> in <module>
# ----> 1 df.Balls_faced= df.Balls_faced.astype('int')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     872         # work around NumPy brokenness, #1987
#     873         if np.issubdtype(dtype.type, np.integer):
# --> 874             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     875
#     876         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: cannot convert float NaN to integer

# %%
df.isnull().any()
# Out:
# Player           False
# Matches          False
# Inns             False
# Not_outs         False
# Runs             False
# Highest_score    False
# Average          False
# Balls_faced       True
# Strike_rate      False
# 100              False
# 50               False
# 0                False
# 4s               False
# 6s               False
# Rookie_year      False
# Final_year       False
# Country          False
# dtype: bool

# %%
df[df.Balls_faced.isna()==1]
# Out:
#              Player  Matches  Inns  Not_outs  Runs  Highest_score  Average  \
# 8        ED Weekes        48    81         5  4455            207    58.61
# 14      CL Walcott        44    74         7  3798            220    56.68
# 57  Hon.FS Jackson        20    33         4  1415            144    48.79
#
#    Balls_faced  Strike_rate  100  50  0   4s  6s  Rookie_year  Final_year  \
# 8          NaN          0.0   15  19  6  258   2         1948        1958
# 14         NaN          0.0   15  14  1  107  11         1948        1960
# 57         NaN          0.0    5   6  3   51   0         1893        1905
#
#    Country
# 8       WI
# 14      WI
# 57     ENG

# %%
df.Balls_faced = df.Balls_faced.fillna(0)

# %%
df[df.Balls_faced.isna()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Matches, Inns, Not_outs, Runs, Highest_score, Average, Balls_faced, Strike_rate, 100, 50, 0, 4s, 6s, Rookie_year, Final_year, Country]
# Index: []

# %%
df.isnull().any()
# Out:
# Player           False
# Matches          False
# Inns             False
# Not_outs         False
# Runs             False
# Highest_score    False
# Average          False
# Balls_faced      False
# Strike_rate      False
# 100              False
# 50               False
# 0                False
# 4s               False
# 6s               False
# Rookie_year      False
# Final_year       False
# Country          False
# dtype: bool

# %%
df.Balls_faced= df.Balls_faced.astype('int')

# %%
df.dtypes
# Out:
# Player            object
# Matches            int64
# Inns               int64
# Not_outs           int64
# Runs               int64
# Highest_score      int32
# Average          float64
# Balls_faced        int32
# Strike_rate      float64
# 100                int64
# 50                 int64
# 0                  int64
# 4s                 int64
# 6s                 int64
# Rookie_year        int32
# Final_year         int32
# Country           object
# dtype: object

# %%
# Career Length (Final Year - Rookie Year)

# %%
df['Career_length'] = df['Final_year']-df['Rookie_year']

# %%
df.head()
# Out:
#         Player  Matches  Inns  Not_outs  Runs  Highest_score  Average  \
# 0  DG Bradman        52    80        10  6996            334    99.94
# 1    AC Voges        20    31         7  1485            269    61.87
# 2    HC Brook        13    21         1  1231            186    61.55
# 3  RG Pollock        23    41         4  2256            274    60.97
# 4  GA Headley        22    40         4  2190            270    60.83
#
#    Balls_faced  Strike_rate  100  50  0   4s  6s  Rookie_year  Final_year  \
# 0         9800        58.60   29  13  7  626   6         1928        1948
# 1         2667        55.68    5   4  2  186   5         2015        2016
# 2         1351        91.11    4   8  1  146  24         2022        2024
# 3         1707        54.48    7  11  1  246  11         1963        1970
# 4          416        56.00   10   5  2  104   1         1930        1954
#
#   Country  Career_length
# 0     AUS             20
# 1     AUS              1
# 2     ENG              2
# 3      SA              7
# 4      WI             24

# %%
# average career length of players

# %%
df.Career_length.mean()
# Out:
# 13.209677419354838

# %%
# average batting strike rate who played over 10 years

# %%
df[df['Career_length']>10]['Strike_rate'].mean()
# Out:
# 47.947272727272725

# %%
# number of player before 1970

# %%
df[df['Rookie_year']<1960]['Player'].count()
# Out:
# 23

# %%
# max highest innings score by country

# %%
df.groupby('Country')['Highest_score'].max()
# Out:
# Country
# AUS        380
# ENG        364
# ICC/IND    319
# ICC/PAK    329
# ICC/SA     277
# ICC/WI     400
# IND        254
# NZ         251
# PAK        313
# SA         278
# SL         374
# WI         365
# ZIM        232
# Name: Highest_score, dtype: int32

# %%
# Average by country of 100s, 50s and 0s

# %%
df.groupby('Country')[['100','50','0']].mean()
# Out:
#                100      50          0
# Country
# AUS      20.625000  28.375   8.562500
# ENG      12.384615  21.000   4.307692
# ICC/IND  29.500000  47.500  12.000000
# ICC/PAK  25.000000  46.000  15.000000
# ICC/SA   36.000000  48.000  13.500000
# ICC/WI   34.000000  48.000  17.000000
# IND      29.500000  36.500  10.750000
# NZ       18.500000  22.000   6.000000
# PAK      21.250000  28.000   9.500000
# SA        9.800000  20.200   3.400000
# SL       28.666667  44.000  12.333333
# WI       16.625000  25.625   7.250000
# ZIM      12.000000  27.000   5.000000
